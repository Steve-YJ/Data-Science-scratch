# %% [markdown]
# **[Pandas Home Page](https://www.kaggle.com/learn/pandas)**
#
# ---

# %% [markdown]
# # Introduction
#
# The first step in most data analytics projects is reading the data file. In this exercise, you'll create Series and DataFrame objects, both by hand and by reading data files.
#
# Run the code cell below to load libraries you will need (including code to check your answers).

# %%
import pandas as pd
pd.set_option('max_rows', 5)
from learntools.core import binder; binder.bind(globals())
from learntools.pandas.creating_reading_and_writing import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://i.imgur.com/Ax3pp2A.png)

# %%
df = pd.DataFrame([[30, 21]], columns=['Apple', 'Banana'])
df
# Out:
#    Apple  Banana
# 0     30      21

# %% [markdown]
# 막상 코테를 시작하면 머리가 멍 ~ 해질수 있다는 말씀! 정말 다행인건! Documentation의 도움을 받을 수 있다는 것이지!

# %% [markdown]
# 기본을 단단히 다진다는 마음으로 다시 한 번 해보자!(이번이 거의 5번째일듯!)

# %%
# First, Dictionary
df = pd.DataFrame({"Apple": [30], "Banana": [21]})
df
# Out:
#    Apple  Banana
# 0     30      21

# %%
df = pd.DataFrame({"Apple": [30, 21, 50], "Bananas": [20, 60, 80]})
df
# Out:
#    Apple  Bananas
# 0     30       20
# 1     21       60
# 2     50       80

# %%
# Second, Constructing DataFrame from numpy ndarray:
df = pd.DataFrame([[30, 21]],
                 columns = ['Apple', 'Bananas'])
df
# Out:
#    Apple  Bananas
# 0     30       21

# %%
df = pd.DataFrame([[30, 20],
                   [21, 60],
                   [50, 80]],
                 columns = ['Apple', 'Bananas'])
df
# Out:
#    Apple  Bananas
# 0     30       20
# 1     21       60
# 2     50       80

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
fruits = pd.DataFrame({'Apples': [30], 'Bananas': [21]})

# Check your answer
q1.check()
# Out:
# Correct

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://i.imgur.com/CHPn7ZF.png)

# %%
# Do it by myself!
fruit_sales = pd.DataFrame({'Apples': [35, 41], 'Bananas': [21, 34]},
                           index = ['2017 Sales', '2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
q2.check()
# Out:
# Correct

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
fruit_sales = pd.DataFrame({'Apples': [35, 41], 'Bananas': [21, 34]},
#                           index={'2017 Sales', '2018 Sales'}
# Dictionary는 순서를 정할 수 없다!
                          index=['2017 Sales', '2018 Sales'])

fruit_sales = pd.DataFrame({'Apples':[35, 41], 'Bananas':[21,34]},
                          index=['2017 Sales', '2018 Sales'])

# Check your answer
q2.check()
fruit_sales

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], dtype=object,
                       index=['Flour', 'Milk', 'Eggs', 'Spam'], name = 'Dinner')
ingredients

q3.check()
# Out:
# Correct

# %%
'''
ingredients = pd.Series({'Flour': '4 cups', 'Milk': '1 cup', 'Eggs': '2 large', 
                        'Spam': '1 can'},
                       name='Dinner')
'''
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'],
                        index=['Flour', 'Milk', 'Eggs', 'Spam'],
                       name='Dinner')

ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'],
                       index = ['Flour', 'Milk', 'Eggs', 'Spam'],
                       name='Dinner')

# Check your answer
q3.check()
ingredients

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# 오... 다시보기 정말 잘했다... 왜이리 새로운지...ㅋㅋ

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://i.imgur.com/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv',  index_col=0 ) # index_col: 문자열 이름 또는 열 인덱스로 제공되는 DataFrame의 행레이블로 사용할 열이다.
                                                                                         # index_col = 0을 많이 사용하게 될 것 같은 느낌?
# q4.check()
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
q4.check()
# Out:
# Correct

# %%
reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv', index_col=False)
reviews.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv', index_col=0)

# Check your answer
q4.check()
reviews

# %%
# q4.hint()
q4.solution()
# Out:
# Hint: Note that the csv file begins with an unnamed column of increasing integers. We want this to be used as the index. Check out the description of the `index_col` keyword argument in [the docs for `read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html).

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
animals = pd.DataFrame({'Cows':[12, 20], 'Goats':[22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
animals.to_csv('./cows_and_goats.csv')
q5.check()
# Out:
# Correct

# %%
# Your code goes here

# pandas.DataFrame.to_csv()
# animals.to_csv('./cows_and_goats.csv')
animals.to_csv('./cows_and_goats.csv')


# Check your answer
q5.check()

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# ## Summary
# * DataFrame을 생성하는 것부터 시작!
#     * Dictionary와 같이 생성하는 방법
#     * Numpy array와 같이 생성하는 방법
# * Series 생성
# * 파일을 불러오는 방법 및 저장하는 방법
#     * <code>pd.read_csv()</code>
#         * Unnamed:0를 row의 열로 사용하고 싶다면??: index_col=0
#     * <code>df.to_csv()</code>

# %% [markdown]
# # Keep going
#
# Move on to learn about **[indexing, selecting and assigning](https://www.kaggle.com/residentmario/indexing-selecting-assigning)**.

# %% [markdown]
# ---
# **[Pandas Home Page](https://www.kaggle.com/learn/pandas)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum) to chat with other Learners.*
